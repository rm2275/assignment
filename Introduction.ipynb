# %% [markdown]
# Applied Data Science Capstone - The Battle of Neighborhoods

# %% [markdown]
#  1.Introduction

# %% [markdown]
# New York (NY), is the foremost crowded city within the Joined together States. With an evaluated 2018 populace of 8,398,748 disseminated over a arrive range of around 302.6 square miles. Unused York metropolitan zone is the biggest metropolitan range within the world by urban landmass and is one of the world's most crowded megacities. Individuals have voyage from different parts of the world and occupied Unused York. As diverse workers come from diverse countries in Unused York, they bring with them diverse and one of a kind societies and nourishment cuisines. Diverse cuisines are not as it were enjoyed by foreign born inhabitants of Modern York but moreover by the locals within the city who like attempting diverse nourishment things. Opening a foreign-based nourishment cooking eatery in Unused York would hence be a great trade idea. Indian food reflects an 8,000-year history of different bunches and societies collaboration with the Indian subcontinent, driving to differences of flavors and territorial cuisines found in modern-day India. Afterward, exchange with British and Portuguese impact included to the as of now differing Indian cuisine. In this venture we Dissect diverse neighborhoods in Unused York city and conclude which would be a great neighborhood to open an Indian nourishment eatery. The extend would be accommodating for gathering of people who have moved from India or South Asia to Unused York and are looking to set up eatery commerce within the city. For illustration: Let us say a individual has moved from India to forever live in Unused York and presently he wishes to set up an Indian Nourishment eatery in Unused York to win his living. The Examination would give the group of onlookers experiences around different neighborhoods in Unused York city and offer assistance them in making choice approximately which neighborhood would be most reasonable to begin their commerce. For Illustration: The individual who has moved from India to Modern York can make out from the examination that :

# %% [markdown]
# which neighborhoods have greatest number of Indian Restaurants?

# %% [markdown]
# which neighborhood has least number of restaurants?

# %% [markdown]
# which Neighborhood is best for setting up unused business?

# %% [markdown]
# how much competition is there within the neighborhood from other Indian Restaurants(this can be seen by seeing the rating)？

# %% [markdown]
# 2. Data

# %% [markdown]
# To examine our information and reach a conclusion, we to begin with have to be plan our information. Information arrangement incorporates: cleaning the information and getting the information to a organize where it may be less demanding to work with the information. we bargain will invalid and missing values in our information set in information prepration. Here we'll change over addresses into their proportionate latitude and longitude values and utilize Foursquare API to investigate neighborhoods in Unused York City. We'll utilize the Area insights given by Foursquare API to supply a arrangement to our client.

# %% [markdown]
# In order to segement the neighborhoods and explore them, we will essentially need a dataset that contains the all the boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood. We can load the data from https://cocl.us/new_york_dataset and we can then use geopy library to get the latitude and longitude values of New York City. we can explore the restaurants in the neighborhood, after the required data is ready i.e:

# %% [markdown]
# we have the scopes and longitudes of all the neighborhoods

# %% [markdown]
# we have organized information prepared within the frame of a table having columns: Boroughs, Neighborhood,Latitude,Longitude

# %% [markdown]
# we have produced our Foursquare accreditations i.e client_id and client_secret

# %% [markdown]
# Once our information is ready, we will extricate different highlights from our information utilizing the Foursquare API like: getting the venues(restaurants) inside a indicated radius. filtering indian eateries inside that radius. getting setting subtle elements like tip tally, likes count for a given scene id finding the appraisals of diverse Indian cuisine restaurants within the range which can furthus offer assistance the client who is attempting to build up a unused trade in Unused York getting the photographs of nourishment things of distinctive venues. Find Tips for each Indian eatery All this data can offer assistance our client to induce an idea about the show showcase of indian food eateries and plan superior in propelling his or her possess restaurant. The underneath code cells appear how our information is ready for investigation:

# %%
#importing the required libraries

import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
import requests 
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium 
# !pip install BeautifulSoup4
from bs4 import BeautifulSoup
#import lxml
print('Required Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# ...

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
#loading the data
import json
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
# defining a new variable that includes the feature key from the data.
neighborhoods_data = newyork_data['features']

# %%
# looking at the first item in our data
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %%
# next we transform the data of nested Python dictionaries into a pandas dataframe. So let's start by creating an empty dataframe.

# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
# Now we loop through the data and fill the dataframe one row at a time.

for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
# examining our resultant dataframe

neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
# now we Use geopy library to get the latitude and longitude values of New York City
#In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent ny_explorer

address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
# creating a  map of New York using latitude and longitude values and superimposing Neighborhoods on Top
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# specifying Foursquare API credentials

CLIENT_ID = 'my_client_id_will_be_specified_here' # your Foursquare ID
CLIENT_SECRET = 'my_client_secret_will_be_specified_here' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

# Now, we can utilize the Foursquare API to explore the neighborhoods and segment them
# Out:
# Your credentails:
# CLIENT_ID: my_client_id_will_be_specified_here
# CLIENT_SECRET:my_client_secret_will_be_specified_here
